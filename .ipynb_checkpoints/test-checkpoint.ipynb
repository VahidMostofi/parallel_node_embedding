# %%
import networkx as nx

# %%
input_dir = './data/facebook/'
train_edges_true = set(nx.read_edgelist(input_dir + 'train_edges_true.txt').edges())
train_edges_false = set(nx.read_edgelist(input_dir + 'train_edges_false.txt').edges())
test_edges_true = set(nx.read_edgelist(input_dir + 'test_edges_true.txt').edges())
test_edges_false = set(nx.read_edgelist(input_dir + 'test_edges_false.txt').edges())

# %%
#useless!!!
print(len(train_edges_true.intersection(train_edges_false)))
print(len(train_edges_true.intersection(test_edges_true)))
print(len(train_edges_true.intersection(test_edges_false)))
print('-')
print(len(train_edges_false.intersection(test_edges_true)))
print(len(train_edges_false.intersection(test_edges_false)))
print('-')
print(len(test_edges_true.intersection(test_edges_false)))
# Out:
# 0
# 0
# 0
# -
# 0
# 0
# -
# 0

# %%
test_edges_true
# Out:
# {('1576', '1182'),
#  ('2708', '3024'),
#  ('855', '2180'),
#  ('2429', '3556'),
#  ('1352', '1107'),
#  ('603', '2000'),
#  ('3075', '939'),
#  ('1354', '151'),
#  ('694', '762'),
#  ('1261', '1243'),
#  ('648', '3767'),
#  ('2434', '3908'),
#  ('933', '3327'),
#  ('3374', '3327'),
#  ('1922', '48'),
#  ('872', '3422'),
#  ('1736', '3085'),
#  ('2370', '3276'),
#  ('2584', '3994'),
#  ('3770', '1335'),
#  ('1419', '180'),
#  ('31', '2598'),
#  ('320', '1004'),
#  ('1051', '3528'),
#  ('418', '114'),
#  ('3463', '218'),
#  ('628', '4017'),
#  ('3856', '2282'),
#  ('279', '1024'),
#  ('986', '1833'),
#  ('2936', '1137'),
#  ('2349', '3595'),
#  ('1535', '2483'),
#  ('1262', '2706'),
#  ('3417', '1638'),
#  ('1922', '1932'),
#  ('1445', '3915'),
#  ('273', '461'),
#  ('2583', '609'),
#  ('3516', '1277'),
#  ('93', '533'),
#  ('3578', '2318'),
#  ('345', '2705'),
#  ('2821', '2699'),
#  ('3984', '2899'),
#  ('3243', '431'),
#  ('3296', '3828'),
#  ('301', '3532'),
#  ('2296', '3212'),
# ...
