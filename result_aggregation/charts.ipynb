# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
def draw_first(values, line_value, ks, metric_name, title):
    figure(num=None, figsize=(16, 9), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(ks, values, 'o-')
    plt.title(title)
    plt.ylabel(metric_name)
    plt.xlabel('number of combinations')
    plt.xticks(ks)
    plt.ylim(ymin=0,ymax=1)  
    plt.plot([0,ks[-1]], [line_value,line_value],'-')
    plt.text(2.0, 0.1, u"\u25A0" + 'default node2vec',
        verticalalignment='bottom', horizontalalignment='left',
        transform=ax.transAxes,
        color='orange', fontsize=15)
    plt.text(2.0, 0.2, u"\u25A0" + 'distributed node2vec',
        verticalalignment='bottom', horizontalalignment='left',
        transform=ax.transAxes,
        color='blue', fontsize=15)
    plt.show()

# %%
values = [0.7298, 0.7102, 0.7484, 0.7849, 0.7998]
line_value = 0.8323
ks = [31, 52, 136, 284, 496]
metric_name = "roc"
title = 'ROC values for different number of combinations, batch_count=32, livemocha'
draw_first(values, line_value, ks, metric_name, title)

# %%
values = [0.7420, 0.7447, 0.7835, 0.7849, 0.7998]
line_value = 0.8291
ks = [31, 52, 136, 284, 496]
metric_name = "average precision"
title = 'average precision values for different number of combinations, batch_count=32, livemocha'
draw_first(values, line_value, ks, metric_name, title)

# %%
def draw_second(values, line_value, ks, metric_name, title):
    figure(num=None, figsize=(16, 9), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(ks, values, 'o-')
    plt.title(title)
    plt.ylabel(metric_name)
    plt.xlabel('number of combinations')
    plt.xticks(ks)
    plt.ylim(ymin=0,ymax=1)  
    plt.plot([0,ks[-1]], [line_value,line_value],'-')
    plt.text(2.0, 0.1, u"\u25A0" + 'default node2vec',
        verticalalignment='bottom', horizontalalignment='left',
        transform=ax.transAxes,
        color='orange', fontsize=15)
    plt.text(2.0, 0.2, u"\u25A0" + 'distributed node2vec',
        verticalalignment='bottom', horizontalalignment='left',
        transform=ax.transAxes,
        color='blue', fontsize=15)
    plt.show()

# %%
values = [0.8761, 0.8402, 0.8086, 0.7687]
line_value = 0.8323
ks = [8, 16, 32, 64]
metric_name = "roc"
title = 'ROC values for different batch_counts, maximum combinations, livemocha'
draw_second(values, line_value, ks, metric_name, title)

# %%
values = [0.8948, 0.8687, 0.8450, 0.8111]
line_value = 0.8291
ks = [8, 16, 32, 64]
metric_name = "average precision"
title = 'average precision values for different batch_counts, maximum combinations, livemocha'
draw_second(values, line_value, ks, metric_name, title)
